# %%
# Now, from previous code, the value of 'm'= 100 , 'b'= -120                       

# So,when we start from that line, toh yha se sbkuch kaise move kr rha hai, yeh hm dekhenge

# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in c:\users\munna\anaconda3\lib\site-packages (0.9.7)
# Requirement already satisfied: ipython<10 in c:\users\munna\anaconda3\lib\site-packages (from ipympl) (9.5.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\munna\anaconda3\lib\site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in c:\users\munna\anaconda3\lib\site-packages (from ipympl) (3.10.6)
# Requirement already satisfied: numpy in c:\users\munna\anaconda3\lib\site-packages (from ipympl) (2.1.3)
# Requirement already satisfied: pillow in c:\users\munna\anaconda3\lib\site-packages (from ipympl) (11.1.0)
# Requirement already satisfied: traitlets<6 in c:\users\munna\anaconda3\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: colorama in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: decorator in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\munna\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\munna\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\munna\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\munna\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\munna\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\munna\anaconda3\lib\site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.5)
# Requirement already satisfied: six>=1.5 in c:\users\munna\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\munna\anaconda3\lib\site-packages (from stack_data->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\munna\anaconda3\lib\site-packages (from stack_data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\munna\anaconda3\lib\site-packages (from stack_data->ipython<10->ipympl) (0.2.3)

# %%
# !pip install --upgrade matplotlib ipykernel ipympl
# Out:
# Requirement already satisfied: matplotlib in c:\users\munna\anaconda3\lib\site-packages (3.10.6)
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: ipykernel in c:\users\munna\anaconda3\lib\site-packages (6.30.1)
# Collecting ipykernel
#   Downloading ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipympl in c:\users\munna\anaconda3\lib\site-packages (0.9.7)
# Collecting ipympl
#   Downloading ipympl-0.9.8-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\munna\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\munna\anaconda3\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\munna\anaconda3\lib\site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: colorama in c:\users\munna\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\munna\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\munna\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\munna\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\munna\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\munna\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\munna\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\munna\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\munna\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: wcwidth in c:\users\munna\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\munna\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\munna\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\munna\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: six>=1.5 in c:\users\munna\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\munna\anaconda3\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\munna\anaconda3\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\munna\anaconda3\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 783.2 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/8.1 MB 739.1 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/8.1 MB 739.1 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.0/8.1 MB 807.5 kB/s eta 0:00:09
#    ------ --------------------------------- 1.3/8.1 MB 849.6 kB/s eta 0:00:09
#    ------- -------------------------------- 1.6/8.1 MB 877.7 kB/s eta 0:00:08
#    --------- ------------------------------ 1.8/8.1 MB 900.4 kB/s eta 0:00:07
#    --------- ------------------------------ 1.8/8.1 MB 900.4 kB/s eta 0:00:07
#    ---------- ----------------------------- 2.1/8.1 MB 873.3 kB/s eta 0:00:07
#    ---------- ----------------------------- 2.1/8.1 MB 873.3 kB/s eta 0:00:07
#    ----------- ---------------------------- 2.4/8.1 MB 853.4 kB/s eta 0:00:07
#    ------------ --------------------------- 2.6/8.1 MB 855.8 kB/s eta 0:00:07
#    ------------ --------------------------- 2.6/8.1 MB 855.8 kB/s eta 0:00:07
#    -------------- ------------------------- 2.9/8.1 MB 838.2 kB/s eta 0:00:07
#    -------------- ------------------------- 2.9/8.1 MB 838.2 kB/s eta 0:00:07
#    --------------- ------------------------ 3.1/8.1 MB 845.8 kB/s eta 0:00:06
#    ---------------- ----------------------- 3.4/8.1 MB 843.6 kB/s eta 0:00:06
#    ------------------ --------------------- 3.7/8.1 MB 849.9 kB/s eta 0:00:06
#    ------------------ --------------------- 3.7/8.1 MB 849.9 kB/s eta 0:00:06
#    ------------------- -------------------- 3.9/8.1 MB 832.3 kB/s eta 0:00:06
#    ------------------- -------------------- 3.9/8.1 MB 832.3 kB/s eta 0:00:06
#    -------------------- ------------------- 4.2/8.1 MB 835.0 kB/s eta 0:00:05
#    --------------------- ------------------ 4.5/8.1 MB 844.5 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.7/8.1 MB 846.1 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.7/8.1 MB 846.1 kB/s eta 0:00:05
#    ------------------------ --------------- 5.0/8.1 MB 833.1 kB/s eta 0:00:04
#    ------------------------ --------------- 5.0/8.1 MB 833.1 kB/s eta 0:00:04
#    ------------------------- -------------- 5.2/8.1 MB 837.8 kB/s eta 0:00:04
#    --------------------------- ------------ 5.5/8.1 MB 839.3 kB/s eta 0:00:04
#    --------------------------- ------------ 5.5/8.1 MB 839.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 5.8/8.1 MB 830.7 kB/s eta 0:00:03
#    ----------------------------- ---------- 6.0/8.1 MB 831.3 kB/s eta 0:00:03
#    ----------------------------- ---------- 6.0/8.1 MB 831.3 kB/s eta 0:00:03
#    ------------------------------ --------- 6.3/8.1 MB 835.9 kB/s eta 0:00:03
#    -------------------------------- ------- 6.6/8.1 MB 840.8 kB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 840.8 kB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 833.1 kB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 839.8 kB/s eta 0:00:02
#    ------------------------------------ --- 7.3/8.1 MB 843.6 kB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 843.6 kB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 848.2 kB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 848.2 kB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 839.8 kB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 839.1 kB/s eta 0:00:00
# Downloading ipykernel-7.1.0-py3-none-any.whl (117 kB)
# Downloading ipympl-0.9.8-py3-none-any.whl (515 kB)
# Installing collected packages: matplotlib, ipykernel, ipympl
#
#   Attempting uninstall: matplotlib
#
#     Found existing installation: matplotlib 3.10.6
#
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#     Uninstalling matplotlib-3.10.6:
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.6
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#    ---------------------------------------- 0/3 [matplotlib]
#   Attempting uninstall: ipykernel
#    ---------------------------------------- 0/3 [matplotlib]
#    ------------- -------------------------- 1/3 [ipykernel]
#     Found existing installation: ipykernel 6.30.1
#    ------------- -------------------------- 1/3 [ipykernel]
#     Uninstalling ipykernel-6.30.1:
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#       Successfully uninstalled ipykernel-6.30.1
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#    ------------- -------------------------- 1/3 [ipykernel]
#   Attempting uninstall: ipympl
#    ------------- -------------------------- 1/3 [ipykernel]
#     Found existing installation: ipympl 0.9.7
#    ------------- -------------------------- 1/3 [ipykernel]
#     Uninstalling ipympl-0.9.7:
#    ------------- -------------------------- 1/3 [ipykernel]
#       Successfully uninstalled ipympl-0.9.7
#    ------------- -------------------------- 1/3 [ipykernel]
#    -------------------------- ------------- 2/3 [ipympl]
#    ---------------------------------------- 3/3 [ipympl]
#
# Successfully installed ipykernel-7.1.0 ipympl-0.9.8 matplotlib-3.10.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 6.0.7 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.5.0 which is incompatible.
# spyder-kernels 3.0.5 requires ipykernel<7,>=6.29.3, but you have ipykernel 7.1.0 which is incompatible.
# spyder-kernels 3.0.5 requires ipython!=8.17.1,<9,>=8.13.0; python_version > "3.8", but you have ipython 9.5.0 which is incompatible.

# %%
from sklearn.datasets import make_regression

import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

# %%
plt.scatter(X,y)      
plt.show()

# %%
b = 100         # you can take any random value of 'm' and 'b', a/c to your choice
m = -120        # we store here hr pichla wala 'm' & 'b', bcz we have to plot the graph
lr = 0.001

all_b = []
all_m = []
all_cost = []

epochs = 30

for i in range(epochs):
    slope_b = 0
    slope_m = 0
    cost = 0

    for j in range(X.shape[0]):
        
        slope_b = slope_b - 2 * (y[j] - (m * X[j]) - b)
        slope_m = slope_m - 2 * (y[j] - (m * X[j]) - b) * X[j]
        cost = cost + (y[j] - m * X[j] - b) ** 2

    b = b - (lr * slope_b)
    m = m - (lr * slope_m)
    all_b.append(b)
    all_m.append(m)
    all_cost.append(cost)

# %%
fig, ax = plt.subplots(figsize=(9,5))
fig.set_tight_layout(True)

x_i = np.arange(-3, 3, 0.1)
y_i = x_i*(-27) -150
ax.scatter(X, y)
line, = ax.plot(x_i, x_i*50 - 4, 'r-', linewidth=2)

def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*all_m[i] + all_b[i])           
    ax.set_xlabel(label)
    return line, ax

anim = FuncAnimation(fig, update, repeat=True, frames=epochs, interval=500)

f = r"animation4.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

#from IPython.display import HTML
#HTML(anim.to_jshtml())

# %%
# Cost function
# creating a blank window 
# for the animation 
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(0, 4500000)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_cost[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation5.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

# %%
# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(-10, 160)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], []    
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_b[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation6.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

# %%
# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(-150, 50)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], []         
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_m[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation7.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)
